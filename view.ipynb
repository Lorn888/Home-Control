# %%
import pandas as pd

logs = pd.read_csv('path_to_your_output_csv_file.csv')

# %%
logs
# Out:
#                         Timestamp                             Log Level  \
# 0     [10/08/2024, 17:54:58]      [TplinkSmarthome]
# 1     [10/08/2024, 17:54:58]      [TplinkSmarthome]
# 2     [10/08/2024, 17:54:58]  [TplinkSmarthome.API]
# 3     [10/08/2024, 17:54:58]  [TplinkSmarthome.API]
# 4     [10/08/2024, 17:54:58]  [TplinkSmarthome.API]
# ...                           ...                                   ...
# 5339  [10/08/2024, 19:21:20]  [TplinkSmarthome.API]
# 5340  [10/08/2024, 19:21:20]  [TplinkSmarthome.API]
# 5341  [10/08/2024, 19:21:20]      [TplinkSmarthome]
# 5342  [10/08/2024, 19:21:20]      [TplinkSmarthome]
# 5343  [10/08/2024, 19:21:20]      [TplinkSmarthome]
#
#                                                 Message
# 0                             refreshEmeter()
# 1     Scheduling next run of refreshEmeter() in...
# 2     client.sendDiscovery(255.255.255.255, [],...
# 3     client.startDiscovery(): socket:message F...
# ...
